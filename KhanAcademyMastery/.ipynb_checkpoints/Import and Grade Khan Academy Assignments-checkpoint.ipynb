# %%
import glob
import pandas as pd

path = r'C:\Users\kcoapman\Dropbox\1819 WPHS Assessment\Khan Academy Grading\Q4 Khan Academy Work'
filenames = glob.glob(path + "/*.csv")
nAssignments = len(filenames)

# %%
## Create Data Frame with Names
DF_temp = pd.read_csv(filenames[0])
GradeFrame = pd.DataFrame(index=DF_temp.iloc[:,1])
StudentNames = GradeFrame.index

# %%
## Read in Multiple Assignments


for name in filenames:
    DF_temp = pd.read_csv(name, engine = 'python')
    AssignmentName = DF_temp.iloc[1,0]
    DFColumns = DF_temp.columns.values
    DFColumns[3] = AssignmentName
    DF_temp.columns = DFColumns
    DF_subset = pd.DataFrame(data=DF_temp.loc[:,AssignmentName])
    DF_subset.index = StudentNames
    GradeFrame = pd.concat([GradeFrame, DF_subset], axis=1)

GradeFrame.head()

GradeFrame.to_excel('CompleteKAGrades.xlsx')

GradeFrame.head()
# Out:
#                     Estimating limit values from graphs  \
# Student Name
# Abdulrazaq Surakat                                  4.0
# Abigail Tatambo                                     4.0
# Alex25fcb                                           NaN
# Alexander Roldan                                    NaN
# Alexander Roldan                                    3.0
#
#                     Factor polynomials: quadratic methods  \
# Student Name
# Abdulrazaq Surakat                                    4.0
# Abigail Tatambo                                       4.0
# Alex25fcb                                             NaN
# Alexander Roldan                                      NaN
# Alexander Roldan                                      4.0
#
#                     Identify function transformations  \
# Student Name
# Abdulrazaq Surakat                                4.0
# Abigail Tatambo                                   4.0
# Alex25fcb                                         NaN
# Alexander Roldan                                  NaN
# Alexander Roldan                                  3.0
#
#                     Increasing and decreasing intervals  \
# Student Name
# Abdulrazaq Surakat                                  4.0
# Abigail Tatambo                                     4.0
# Alex25fcb                                           NaN
# Alexander Roldan                                    NaN
# Alexander Roldan                                    4.0
#
#                     Limits at infinity of quotients  \
# Student Name
# Abdulrazaq Surakat                              7.0
# Abigail Tatambo                                 7.0
# Alex25fcb                                       NaN
# Alexander Roldan                                NaN
# Alexander Roldan                                7.0
#
#                     Limits at infinity of quotients with trig  \
# Student Name
# Abdulrazaq Surakat                                        4.0
# Abigail Tatambo                                           4.0
# Alex25fcb                                                 NaN
# Alexander Roldan                                          NaN
# Alexander Roldan                                          2.0
#
#                     Multiply & divide rational expressions  \
# Student Name
# Abdulrazaq Surakat                                     4.0
# Abigail Tatambo                                        4.0
# Alex25fcb                                              NaN
# Alexander Roldan                                       NaN
# Alexander Roldan                                       2.0
#
#                     Positive and negative intervals  \
# Student Name
# Abdulrazaq Surakat                              4.0
# Abigail Tatambo                                 4.0
# Alex25fcb                                       NaN
# Alexander Roldan                                NaN
# Alexander Roldan                                4.0
#
#                     Simplify rational expressions: common binomial factors  \
# Student Name
# Abdulrazaq Surakat                                                4.0
# Abigail Tatambo                                                   4.0
# Alex25fcb                                                         NaN
# Alexander Roldan                                                  NaN
# Alexander Roldan                                                  4.0
#
#                     Solve sinusoidal equations (basic)  \
# Student Name
# Abdulrazaq Surakat                                 4.0
# Abigail Tatambo                                    1.0
# Alex25fcb                                          NaN
# Alexander Roldan                                   NaN
# Alexander Roldan                                   3.0
#
#                     Trig values of special angles  \
# Student Name
# Abdulrazaq Surakat                            4.0
# Abigail Tatambo                               4.0
# Alex25fcb                                     NaN
# Alexander Roldan                              NaN
# Alexander Roldan                              3.0
#
#                     Trig values of special angles
# Student Name
# Abdulrazaq Surakat                            4.0
# Abigail Tatambo                               4.0
# Alex25fcb                                     NaN
# Alexander Roldan                              NaN
# Alexander Roldan                              3.0

# %%
# Output the Final HW Grade by summing the rows into a final matrix
