# %%
import glob
import pandas as pd

path = r'C:\Users\kyled\Dropbox\1819 WPHS Assessment\Khan Academy Grading\Q4 Khan Academy Work'
filenames = glob.glob(path + "/*.csv")
nAssignments = len(filenames)

# %%
## Create Data Frame with Names
DF_temp = pd.read_csv(filenames[0])
GradeFrame = pd.DataFrame(index=DF_temp.iloc[:,1])
StudentNames = GradeFrame.index

# %%
## Read in Multiple Assignments


for name in filenames:
    DF_temp = pd.read_csv(name, engine = 'python')
    AssignmentName = DF_temp.iloc[1,0]
    DFColumns = DF_temp.columns.values
    DFColumns[3] = AssignmentName
    DF_temp.columns = DFColumns
    DF_subset = pd.DataFrame(data=DF_temp.loc[:,AssignmentName])
    DF_subset.index = StudentNames
    GradeFrame = pd.concat([GradeFrame, DF_subset], axis=1)

GradeFrame.head()

GradeFrame.to_excel('CompleteKAGrades.xlsx')

GradeFrame
# Out:
#                         Interval of convergence  Lagrange error bound  \
# Student Name
# Agba, Charles                               4.0                   4.0
# Blackwell, Noah-Simone                      4.0                   4.0
# Blanco, Carla                               NaN                   NaN
# Bryan, She'Mille                            NaN                   NaN
# Campos, Nathan                              NaN                   NaN
# Carambot, Jayden                            3.0                   2.0
# Collazo, Jayda                              NaN                   0.0
# Darling, Prashanti                          1.0                   2.0
# Gopre, Beverly                              2.0                   2.0
# Harris, Saharah                             NaN                   NaN
# Harvey, Sade                                4.0                   4.0
# Hernandez, Hezekiah                         0.0                   2.0
# Hill, Samijah                               NaN                   0.0
# Konadu, Nakeba                              NaN                   NaN
# Milfort, Wilschnaida                        NaN                   NaN
# Mitchell-Smith, Simone                      NaN                   NaN
# Norman, Jerelyn                             3.0                   4.0
# Nyantakyi, Rachel                           4.0                   4.0
# Oppong, Amanda                              1.0                   2.0
# Ortiz, Jorge                                NaN                   NaN
# Quartsin, Bridrich                          4.0                   4.0
# Quaye, Rebecca                              1.0                   3.0
# Sharpe, Cionna                              4.0                   4.0
# Sharpe, Deja                                4.0                   4.0
# Siguencia, Angel                            3.0                   3.0
# Tamay, Jenifer                              4.0                   2.0
# Taracena, Brianna                           2.0                   1.0
# Uqdah, Na'im                                NaN                   NaN
# Valentin, Bianca                            3.0                   3.0
# White, Paul                                 1.0                   NaN
# Whittington, Kayla                          NaN                   NaN
#
#                         Taylor & Maclaurin polynomials  Integration by parts  \
# Student Name
# Agba, Charles                                      3.0                   3.0
# Blackwell, Noah-Simone                             4.0                   4.0
# Blanco, Carla                                      NaN                   NaN
# Bryan, She'Mille                                   NaN                   NaN
# Campos, Nathan                                     NaN                   NaN
# Carambot, Jayden                                   4.0                   NaN
# Collazo, Jayda                                     2.0                   4.0
# Darling, Prashanti                                 3.0                   1.0
# Gopre, Beverly                                     4.0                   4.0
# Harris, Saharah                                    NaN                   4.0
# Harvey, Sade                                       4.0                   3.0
# Hernandez, Hezekiah                                4.0                   4.0
# Hill, Samijah                                      3.0                   NaN
# Konadu, Nakeba                                     3.0                   3.0
# Milfort, Wilschnaida                               NaN                   NaN
# Mitchell-Smith, Simone                             2.0                   3.0
# Norman, Jerelyn                                    3.0                   2.0
# Nyantakyi, Rachel                                  4.0                   4.0
# Oppong, Amanda                                     3.0                   4.0
# Ortiz, Jorge                                       1.0                   NaN
# Quartsin, Bridrich                                 2.0                   4.0
# Quaye, Rebecca                                     2.0                   0.0
# Sharpe, Cionna                                     4.0                   NaN
# Sharpe, Deja                                       4.0                   NaN
# Siguencia, Angel                                   3.0                   3.0
# Tamay, Jenifer                                     3.0                   4.0
# Taracena, Brianna                                  NaN                   NaN
# Uqdah, Na'im                                       NaN                   NaN
# Valentin, Bianca                                   4.0                   4.0
# White, Paul                                        3.0                   NaN
# Whittington, Kayla                                 NaN                   1.0
#
#                         Integration by parts: definite integrals  \
# Student Name
# Agba, Charles                                                4.0
# Blackwell, Noah-Simone                                       4.0
# Blanco, Carla                                                NaN
# Bryan, She'Mille                                             NaN
# Campos, Nathan                                               NaN
# Carambot, Jayden                                             NaN
# Collazo, Jayda                                               4.0
# Darling, Prashanti                                           NaN
# Gopre, Beverly                                               0.0
# Harris, Saharah                                              4.0
# Harvey, Sade                                                 3.0
# Hernandez, Hezekiah                                          2.0
# Hill, Samijah                                                NaN
# Konadu, Nakeba                                               NaN
# Milfort, Wilschnaida                                         NaN
# Mitchell-Smith, Simone                                       3.0
# Norman, Jerelyn                                              NaN
# Nyantakyi, Rachel                                            4.0
# Oppong, Amanda                                               3.0
# Ortiz, Jorge                                                 NaN
# Quartsin, Bridrich                                           4.0
# Quaye, Rebecca                                               3.0
# Sharpe, Cionna                                               NaN
# Sharpe, Deja                                                 NaN
# Siguencia, Angel                                             3.0
# Tamay, Jenifer                                               4.0
# Taracena, Brianna                                            NaN
# Uqdah, Na'im                                                 NaN
# Valentin, Bianca                                             4.0
# White, Paul                                                  NaN
# Whittington, Kayla                                           NaN
#
#                         Integration with partial fractions
# Student Name
# Agba, Charles                                          4.0
# Blackwell, Noah-Simone                                 4.0
# Blanco, Carla                                          NaN
# Bryan, She'Mille                                       NaN
# Campos, Nathan                                         NaN
# Carambot, Jayden                                       NaN
# Collazo, Jayda                                         4.0
# Darling, Prashanti                                     1.0
# Gopre, Beverly                                         NaN
# Harris, Saharah                                        4.0
# Harvey, Sade                                           0.0
# Hernandez, Hezekiah                                    0.0
# Hill, Samijah                                          NaN
# Konadu, Nakeba                                         NaN
# Milfort, Wilschnaida                                   NaN
# Mitchell-Smith, Simone                                 NaN
# Norman, Jerelyn                                        NaN
# Nyantakyi, Rachel                                      NaN
# Oppong, Amanda                                         NaN
# Ortiz, Jorge                                           NaN
# Quartsin, Bridrich                                     4.0
# Quaye, Rebecca                                         0.0
# Sharpe, Cionna                                         NaN
# Sharpe, Deja                                           NaN
# Siguencia, Angel                                       4.0
# Tamay, Jenifer                                         4.0
# Taracena, Brianna                                      NaN
# Uqdah, Na'im                                           NaN
# Valentin, Bianca                                       1.0
# White, Paul                                            NaN
# Whittington, Kayla                                     NaN

# %%
# Output the Final HW Grade by summing the rows into a final matrix
